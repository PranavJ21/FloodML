# %%
import sys
print(sys.executable)
# Out:
# C:\Users\USER\Desktop\FloodML\flood_env\Scripts\python.exe

# %%
import pandas as pd
import numpy as np
import geopandas as gpd
import sklearn
import xgboost as xgb
import shap
import folium
import rasterio
print("pandas:", pd.__version__)
print("geopandas:", gpd.__version__)
print("sklearn:", sklearn.__version__)
print("xgboost:", xgb.__version__)
print("shap:", shap.__version__)
print("All good — environment ready!")
# Out:
# pandas: 3.0.1
# geopandas: 1.1.3
# sklearn: 1.8.0
# xgboost: 3.2.0
# shap: 0.51.0
# All good — environment ready!
